# %% [markdown]
# # Project 7 - Notes for choosing hyperparameter for other variables _MLP
#
# **Author: Linh Nguyen**<br>
#
# **StudentID: 23161711**<br>
#
# **Date: Sep 2022**

# %% [markdown]
# # 1. Load data and import package

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Capstone_project
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Capstone_project

# %%
import numpy as np
import pandas as pd

from sklearn.impute import SimpleImputer
from tensorflow import keras
from tensorflow.keras.layers import TextVectorization
from tensorflow.keras.layers import Embedding
from tensorflow.keras import layers
import seaborn as sns
from matplotlib import pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
import  tensorflow as tf
from gensim.models import KeyedVectors
from sklearn.model_selection import cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix,ConfusionMatrixDisplay,classification_report, roc_auc_score

# %%
! ls /content/drive/MyDrive/Capstone_project/raw
# Out:
# diagnosis.csv  icd9toicd10cmgem.csv  pyxis.csv	 vitalsign.csv
# edstays.csv    medrecon.csv	     triage.csv

# %% [markdown]
# # 2. Data cleansing

# %%
edstays = pd.read_csv('raw/edstays.csv')
edstays['y_var_adm_text'] = edstays['disposition']
edstays.loc[edstays['y_var_adm_text'] == 'TRANSFER', 'y_var_adm_text'] = 'ADMITTED'
edstays.loc[edstays['y_var_adm_text'] == 'ELOPED','y_var_adm_text'] = 'MISSING'
edstays.loc[edstays['y_var_adm_text'] == 'LEFT WITHOUT BEING SEEN','y_var_adm_text'] = 'MISSING'
edstays.loc[edstays['y_var_adm_text'] == 'OTHER','y_var_adm_text'] = 'MISSING'
edstays.loc[edstays['y_var_adm_text'] == 'LEFT AGAINST MEDICAL ADVICE','y_var_adm_text'] = 'MISSING'
edstays.loc[edstays['y_var_adm_text'] == 'EXPIRED','y_var_adm_text'] = 'MISSING'
edstays_admit = edstays[edstays['y_var_adm_text'] !='MISSING'].reset_index(drop = True)
edstays_admit['key'] = edstays_admit['subject_id'].astype(str)+'_'+edstays_admit['stay_id'].astype(str)

# %%
edstays_admit.loc[edstays_admit['race'].str.contains('WHITE'), 'race_color'] = 'WHITE'
edstays_admit.loc[edstays_admit['race'].str.contains('BLACK'), 'race_color'] = 'BLACK'
edstays_admit.loc[edstays_admit['race'].str.contains('ASIAN'), 'race_color'] = 'ASIAN'
edstays_admit.loc[edstays_admit['race'].str.contains('LATINO'), 'race_color'] = 'HISPANIC/LATINO'
edstays_admit.loc[edstays_admit['race'].str.contains('HISPANIC'), 'race_color'] = 'HISPANIC/LATINO'
edstays_admit.loc[edstays_admit['race_color'].isna(), 'race_color'] = 'OTHER'

# %%
edstays_admit['DateTime_in'] = pd.to_datetime(edstays_admit['intime'], format='%d/%m/%Y %H:%M')
edstays_admit['DateTime_out'] = pd.to_datetime(edstays_admit['outtime'], format='%d/%m/%Y %H:%M')

# %%
edstays_admit['stay'] = edstays_admit['DateTime_out'] - edstays_admit['DateTime_in']

# %%
edstays_admit_1 = edstays_admit.sort_values(by = ['subject_id','DateTime_in'], ascending=True).reset_index(drop=True)

# %%
edstay_hist = {}
for i in range(len(edstays_admit_1)):
    if i == 0:
        edstay_hist[i] = 'NO HISTORY'
    else:
        if edstays_admit_1['subject_id'][i] == edstays_admit_1['subject_id'][i-1]:
            edstay_hist[i] = edstays_admit_1['y_var_adm_text'][i-1]
        else:
            edstay_hist[i] = 'NO HISTORY'

# %%
edstay_laststay = {}
for i in range(len(edstays_admit_1)):
    if i == 0:
        edstay_laststay[i] = np.timedelta64(0, 'D')
    else:
        if edstays_admit_1['subject_id'][i] == edstays_admit_1['subject_id'][i-1]: 
          edstay_laststay[i] = edstays_admit_1['stay'][i-1]+edstay_laststay[i-1]
        else:
            edstay_laststay[i] = np.timedelta64(0, 'D')

# %%
df1 = pd.DataFrame.from_dict(edstay_hist,orient='index')
df1.columns = ['historical_stay_status']
edstays_admit_1 = pd.merge(edstays_admit_1,df1,how = 'left',left_index=True,right_index=True)

# %%
df1 = pd.DataFrame.from_dict(edstay_laststay,orient='index')
df1.columns = ['historical_stay_length']
edstays_admit_1 = pd.merge(edstays_admit_1,df1,how = 'left',left_index=True,right_index=True)

# %%
edstays_admit_1['historical_stay_length_in_day'] = edstays_admit_1['historical_stay_length']/(np.timedelta64(1, 'D'))

# %%
edstays_admit_2 = pd.merge(edstays_admit,edstays_admit_1[['historical_stay_status','historical_stay_length','historical_stay_length_in_day','subject_id','stay_id']],how = 'left',on=['subject_id', 'stay_id'])

# %%
edstays_admit_2.columns
# Out:
# Index(['subject_id', 'hadm_id', 'stay_id', 'intime', 'outtime', 'gender',
#        'race', 'arrival_transport', 'disposition', 'y_var_adm_text', 'key',
#        'race_color', 'DateTime_in', 'DateTime_out', 'stay',
#        'historical_stay_status', 'historical_stay_length',
#        'historical_stay_length_in_day'],
#       dtype='object')

# %%
triage = pd.read_csv('raw/triage.csv')

# %%
edstay_ad = pd.merge(edstays_admit_2,triage,how = 'left',on=['subject_id', 'stay_id'])

# %%
edstay_ad['y_var'] = 0
edstay_ad.loc[edstay_ad['y_var_adm_text'] == 'ADMITTED', 'y_var']  = 1

# %%
edstay_ad.columns
# Out:
# Index(['subject_id', 'hadm_id', 'stay_id', 'intime', 'outtime', 'gender',
#        'race', 'arrival_transport', 'disposition', 'y_var_adm_text', 'key',
#        'race_color', 'DateTime_in', 'DateTime_out', 'stay',
#        'historical_stay_status', 'historical_stay_length',
#        'historical_stay_length_in_day', 'temperature', 'heartrate', 'resprate',
#        'o2sat', 'sbp', 'dbp', 'pain', 'acuity', 'chiefcomplaint', 'y_var'],
#       dtype='object')

# %%
edstay_ad = edstay_ad.drop(['subject_id','hadm_id','stay_id','intime','outtime','race', 'race_color', 'gender',	'disposition','y_var_adm_text','key', 'DateTime_in', 'DateTime_out','stay','historical_stay_length','chiefcomplaint', 'pain'], axis = 1)

# %%
edstay_ad
# Out:
#        arrival_transport historical_stay_status  \
# 0              AMBULANCE             NO HISTORY
# 1              AMBULANCE               ADMITTED
# 2              AMBULANCE               ADMITTED
# 3              AMBULANCE               ADMITTED
# 4              AMBULANCE                   HOME
# ...                  ...                    ...
# 428279           WALK IN               ADMITTED
# 428280           WALK IN             NO HISTORY
# 428281         AMBULANCE               ADMITTED
# 428282           WALK IN             NO HISTORY
# 428283         AMBULANCE             NO HISTORY
#
#         historical_stay_length_in_day  temperature  heartrate  resprate  \
# 0                            0.000000         98.4       70.0      16.0
# 1                            0.175694         98.9       88.0      18.0
# 2                            1.309722         99.4      105.0      18.0
# 3                            0.409722         97.8       87.0      14.0
# 4                            0.972222         98.7       77.0      16.0
# ...                               ...          ...        ...       ...
# 428279                       0.551389         98.8       92.0      18.0
# 428280                       0.000000         98.6       80.0      18.0
# 428281                       1.011111         96.6      112.0      18.0
# 428282                       0.000000         98.1       83.0      18.0
# 428283                       0.000000          NaN        NaN       NaN
#
#         o2sat    sbp    dbp  acuity  y_var
# 0        97.0  106.0   63.0     3.0      1
# 1        97.0  116.0   88.0     3.0      1
# 2        96.0  106.0   57.0     3.0      1
# 3        97.0   71.0   43.0     2.0      0
# 4        98.0   96.0   50.0     2.0      1
# ...       ...    ...    ...     ...    ...
# 428279  100.0  122.0   77.0     3.0      1
# 428280  100.0  161.0  100.0     3.0      1
# 428281  100.0  110.0   82.0     2.0      1
# 428282  100.0  107.0   75.0     2.0      1
# 428283    NaN    NaN    NaN     NaN      1
#
# [428284 rows x 11 columns]

# %%
edstay_ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 428284 entries, 0 to 428283
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   arrival_transport              428284 non-null  object
#  1   historical_stay_status         428284 non-null  object
#  2   historical_stay_length_in_day  428284 non-null  float64
#  3   temperature                    405762 non-null  float64
#  4   heartrate                      412132 non-null  float64
#  5   resprate                       408822 non-null  float64
#  6   o2sat                          408594 non-null  float64
#  7   sbp                            410935 non-null  float64
#  8   dbp                            410124 non-null  float64
#  9   acuity                         422216 non-null  float64
#  10  y_var                          428284 non-null  int64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 39.2+ MB

# %%
updated_edstay_ad = edstay_ad
updated_edstay_ad['temperaturemissing'] = updated_edstay_ad['temperature'].isnull().astype(int)
updated_edstay_ad['heartratemissing'] = updated_edstay_ad['heartrate'].isnull().astype(int)
updated_edstay_ad['respratemissing'] = updated_edstay_ad['resprate'].isnull().astype(int)
updated_edstay_ad['o2satmissing'] = updated_edstay_ad['o2sat'].isnull().astype(int)
updated_edstay_ad['sbpmissing'] = updated_edstay_ad['sbp'].isnull().astype(int)
updated_edstay_ad['dbpmissing'] = updated_edstay_ad['dbp'].isnull().astype(int)
updated_edstay_ad['acuitymissing'] = updated_edstay_ad['acuity'].isnull().astype(int)

# %%
num_attr = edstay_ad.select_dtypes(include=['float64']).columns
cat_attr = edstay_ad.select_dtypes(include=['O']).columns
#bool_attr = edstay_ad.select_dtypes(include=['bool']).columns

# %%
my_imputer = SimpleImputer(strategy = 'median')
updated_edstay_ad[num_attr] = my_imputer.fit_transform(updated_edstay_ad[num_attr])
updated_edstay_ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 428284 entries, 0 to 428283
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   arrival_transport              428284 non-null  object
#  1   historical_stay_status         428284 non-null  object
#  2   historical_stay_length_in_day  428284 non-null  float64
#  3   temperature                    428284 non-null  float64
#  4   heartrate                      428284 non-null  float64
#  5   resprate                       428284 non-null  float64
#  6   o2sat                          428284 non-null  float64
#  7   sbp                            428284 non-null  float64
#  8   dbp                            428284 non-null  float64
#  9   acuity                         428284 non-null  float64
#  10  y_var                          428284 non-null  int64
#  11  temperaturemissing             428284 non-null  int64
#  12  heartratemissing               428284 non-null  int64
#  13  respratemissing                428284 non-null  int64
#  14  o2satmissing                   428284 non-null  int64
#  15  sbpmissing                     428284 non-null  int64
#  16  dbpmissing                     428284 non-null  int64
#  17  acuitymissing                  428284 non-null  int64
# dtypes: float64(8), int64(8), object(2)
# memory usage: 62.1+ MB

# %% [markdown]
# # 3. Split dataset

# %%
#set random index, create train set and validation set from the original train set

#create array of random index
np.random.seed(123)
ind = np.arange(len(updated_edstay_ad))
np.random.shuffle(ind)
#create testing index  = 0 to 0.20 * random index
test_index = ind[:int(len(updated_edstay_ad) * 0.20)]
#create validation index  = 0.20 to 0.30 * random index
val_index = ind[int(len(updated_edstay_ad) * 0.20):int(len(updated_edstay_ad) * 0.30)]
#create train index = 0.30 * random index to end
train_index = ind[int(len(updated_edstay_ad) * 0.30):]

# %%
X_train = updated_edstay_ad.drop('y_var',axis = 1).iloc[train_index]
y_train = updated_edstay_ad['y_var'].iloc[train_index]
X_val = updated_edstay_ad.drop('y_var',axis = 1).iloc[val_index]
y_val = updated_edstay_ad['y_var'].iloc[val_index]
X_test = updated_edstay_ad.drop('y_var',axis = 1).iloc[test_index]
y_test = updated_edstay_ad['y_var'].iloc[test_index]
#Train = updated_edstay_ad.iloc[train_index]
#Test = updated_edstay_ad.iloc[test_index]

# %% [markdown]
# 5. Transform dataset

# %%
trans_pip = ColumnTransformer([
    ("num",StandardScaler(), num_attr),
    ("cat",OneHotEncoder(),cat_attr)
],remainder='passthrough')

# %% [markdown]
# # 4. MLP

# %%
X_train_in = trans_pip.fit_transform(X_train)
X_val = trans_pip.transform(X_val)
X_test = trans_pip.transform(X_test)

# %%
grid_param = [["glorot_uniform",0,"elu"],["glorot_uniform",0.2,"relu"],["he_normal",0,"elu"],["he_normal",0.2,"relu"],
              ["glorot_uniform",0.2,"elu"],["glorot_uniform",0,"relu"],["he_normal",0.2,"elu"],["he_normal",0,"relu"],
              ]

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)
#create model structure as above explanation
def build_model(kernel_initializer = "glorot_uniform", rate = 0.2, activation = "relu"):
    #set initial hyperparameter
    model = keras.models.Sequential()
    model.add(keras.layers.Dense(100, activation=activation,kernel_initializer = kernel_initializer))
    #create first hidden layers
    model.add(keras.layers.Dropout(rate = rate))
    model.add(keras.layers.Dense(50, activation=activation,kernel_initializer = kernel_initializer))
    #create second hidden layers
    model.add(keras.layers.Dropout(rate = rate))
    model.add(keras.layers.Dense(1, activation="sigmoid"))
    #create output layers
    optimizer = tf.keras.optimizers.SGD()
    #create optimizer with SGD
    
    model.compile(loss = 'binary_crossentropy', optimizer = optimizer, metrics = ["accuracy"])
    #model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=["accuracy"])
    #Compile model with loss function, optimizer and metrics of accuracy
    return model

# %%
for i in range(len(grid_param)):
  model = build_model(kernel_initializer = grid_param[i][0], rate = grid_param[i][1], activation = grid_param[i][2])
  weights = {0:1-(sum(y_train)/len(y_train)),1:sum(y_train)/len(y_train)}
  model.fit(X_train_in, y_train, epochs=100,validation_data=(X_val, y_val), callbacks = [keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)], class_weight = weights)
  y_pred_valid = model.predict(X_val)
  print(grid_param[i])
  print("roc auc for validation set:", roc_auc_score(y_val, y_pred_valid))
  y_pred_valid_class = np.where(y_pred_valid>0.5, 1, 0)
  print("f1 score for validation set:", f1_score(y_val, y_pred_valid_class))
# Out:
# Epoch 1/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2636 - accuracy: 0.7129 - val_loss: 0.5651 - val_accuracy: 0.7214
# Epoch 2/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2578 - accuracy: 0.7218 - val_loss: 0.5664 - val_accuracy: 0.7225
# Epoch 3/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2564 - accuracy: 0.7237 - val_loss: 0.5763 - val_accuracy: 0.7209
# Epoch 4/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2556 - accuracy: 0.7250 - val_loss: 0.5717 - val_accuracy: 0.7262
# Epoch 5/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2551 - accuracy: 0.7251 - val_loss: 0.5789 - val_accuracy: 0.7221
# Epoch 6/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2547 - accuracy: 0.7260 - val_loss: 0.5786 - val_accuracy: 0.7243
# Epoch 7/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2543 - accuracy: 0.7258 - val_loss: 0.5809 - val_accuracy: 0.7231
# Epoch 8/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2540 - accuracy: 0.7260 - val_loss: 0.5872 - val_accuracy: 0.7237
# Epoch 9/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2537 - accuracy: 0.7263 - val_loss: 0.5931 - val_accuracy: 0.7237
# Epoch 10/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2535 - accuracy: 0.7263 - val_loss: 0.5954 - val_accuracy: 0.7223
# Epoch 11/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2534 - accuracy: 0.7268 - val_loss: 0.5867 - val_accuracy: 0.7264
# ['glorot_uniform', 0, 'elu']
# roc auc for validation set: 0.7972900283875811
# f1 score for validation set: 0.5987396397013494
# Epoch 1/100
# 9369/9369 [==============================] - 24s 3ms/step - loss: 0.2719 - accuracy: 0.6982 - val_loss: 0.5667 - val_accuracy: 0.7211
# Epoch 2/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2630 - accuracy: 0.7174 - val_loss: 0.5659 - val_accuracy: 0.7206
# Epoch 3/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2607 - accuracy: 0.7192 - val_loss: 0.5730 - val_accuracy: 0.7199
# Epoch 4/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2596 - accuracy: 0.7200 - val_loss: 0.5711 - val_accuracy: 0.7220
# Epoch 5/100
# 9369/9369 [==============================] - 23s 3ms/step - loss: 0.2587 - accuracy: 0.7207 - val_loss: 0.5665 - val_accuracy: 0.7209
# Epoch 6/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2578 - accuracy: 0.7215 - val_loss: 0.5648 - val_accuracy: 0.7234
# Epoch 7/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2573 - accuracy: 0.7214 - val_loss: 0.5623 - val_accuracy: 0.7239
# Epoch 8/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2571 - accuracy: 0.7222 - val_loss: 0.5610 - val_accuracy: 0.7227
# Epoch 9/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2568 - accuracy: 0.7227 - val_loss: 0.5646 - val_accuracy: 0.7226
# Epoch 10/100
# 9369/9369 [==============================] - 24s 3ms/step - loss: 0.2564 - accuracy: 0.7224 - val_loss: 0.5609 - val_accuracy: 0.7221
# Epoch 11/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2562 - accuracy: 0.7228 - val_loss: 0.5544 - val_accuracy: 0.7249
# Epoch 12/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2559 - accuracy: 0.7233 - val_loss: 0.5556 - val_accuracy: 0.7238
# Epoch 13/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2554 - accuracy: 0.7237 - val_loss: 0.5561 - val_accuracy: 0.7251
# Epoch 14/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2556 - accuracy: 0.7236 - val_loss: 0.5570 - val_accuracy: 0.7223
# Epoch 15/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2553 - accuracy: 0.7245 - val_loss: 0.5527 - val_accuracy: 0.7243
# Epoch 16/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2549 - accuracy: 0.7243 - val_loss: 0.5498 - val_accuracy: 0.7246
# Epoch 17/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2548 - accuracy: 0.7245 - val_loss: 0.5498 - val_accuracy: 0.7258
# Epoch 18/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2546 - accuracy: 0.7246 - val_loss: 0.5537 - val_accuracy: 0.7232
# Epoch 19/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2546 - accuracy: 0.7246 - val_loss: 0.5485 - val_accuracy: 0.7248
# Epoch 20/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2544 - accuracy: 0.7254 - val_loss: 0.5490 - val_accuracy: 0.7254
# Epoch 21/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2542 - accuracy: 0.7251 - val_loss: 0.5511 - val_accuracy: 0.7251
# Epoch 22/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2541 - accuracy: 0.7253 - val_loss: 0.5485 - val_accuracy: 0.7258
# Epoch 23/100
# 9369/9369 [==============================] - 24s 3ms/step - loss: 0.2540 - accuracy: 0.7256 - val_loss: 0.5473 - val_accuracy: 0.7271
# Epoch 24/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2539 - accuracy: 0.7258 - val_loss: 0.5452 - val_accuracy: 0.7262
# Epoch 25/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2539 - accuracy: 0.7258 - val_loss: 0.5469 - val_accuracy: 0.7251
# Epoch 26/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2536 - accuracy: 0.7259 - val_loss: 0.5459 - val_accuracy: 0.7242
# Epoch 27/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2538 - accuracy: 0.7256 - val_loss: 0.5436 - val_accuracy: 0.7275
# Epoch 28/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2538 - accuracy: 0.7259 - val_loss: 0.5493 - val_accuracy: 0.7242
# Epoch 29/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2534 - accuracy: 0.7263 - val_loss: 0.5501 - val_accuracy: 0.7250
# Epoch 30/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2536 - accuracy: 0.7261 - val_loss: 0.5500 - val_accuracy: 0.7229
# Epoch 31/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2534 - accuracy: 0.7265 - val_loss: 0.5418 - val_accuracy: 0.7272
# Epoch 32/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2534 - accuracy: 0.7263 - val_loss: 0.5441 - val_accuracy: 0.7257
# Epoch 33/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2532 - accuracy: 0.7262 - val_loss: 0.5408 - val_accuracy: 0.7275
# Epoch 34/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2531 - accuracy: 0.7269 - val_loss: 0.5441 - val_accuracy: 0.7242
# Epoch 35/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2530 - accuracy: 0.7266 - val_loss: 0.5431 - val_accuracy: 0.7247
# Epoch 36/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2529 - accuracy: 0.7270 - val_loss: 0.5421 - val_accuracy: 0.7261
# Epoch 37/100
# 9369/9369 [==============================] - 24s 3ms/step - loss: 0.2529 - accuracy: 0.7275 - val_loss: 0.5424 - val_accuracy: 0.7265
# Epoch 38/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2528 - accuracy: 0.7269 - val_loss: 0.5417 - val_accuracy: 0.7265
# Epoch 39/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2532 - accuracy: 0.7273 - val_loss: 0.5471 - val_accuracy: 0.7239
# Epoch 40/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2529 - accuracy: 0.7272 - val_loss: 0.5436 - val_accuracy: 0.7263
# Epoch 41/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2530 - accuracy: 0.7272 - val_loss: 0.5454 - val_accuracy: 0.7252
# Epoch 42/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2530 - accuracy: 0.7269 - val_loss: 0.5420 - val_accuracy: 0.7265
# Epoch 43/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2526 - accuracy: 0.7272 - val_loss: 0.5430 - val_accuracy: 0.7259
# ['glorot_uniform', 0.2, 'relu']
# roc auc for validation set: 0.8005821610731503
# f1 score for validation set: 0.5897400055912775
# Epoch 1/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2593 - accuracy: 0.7191 - val_loss: 0.5702 - val_accuracy: 0.7236
# Epoch 2/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2553 - accuracy: 0.7249 - val_loss: 0.5691 - val_accuracy: 0.7243
# Epoch 3/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2543 - accuracy: 0.7265 - val_loss: 0.5735 - val_accuracy: 0.7219
# Epoch 4/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2538 - accuracy: 0.7271 - val_loss: 0.5626 - val_accuracy: 0.7276
# Epoch 5/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2535 - accuracy: 0.7272 - val_loss: 0.5573 - val_accuracy: 0.7230
# Epoch 6/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2532 - accuracy: 0.7269 - val_loss: 0.5548 - val_accuracy: 0.7250
# Epoch 7/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2529 - accuracy: 0.7272 - val_loss: 0.5530 - val_accuracy: 0.7251
# Epoch 8/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2529 - accuracy: 0.7272 - val_loss: 0.5614 - val_accuracy: 0.7236
# Epoch 9/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2530 - accuracy: 0.7276 - val_loss: 0.5690 - val_accuracy: 0.7231
# Epoch 10/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2526 - accuracy: 0.7275 - val_loss: 0.5633 - val_accuracy: 0.7232
# Epoch 11/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2526 - accuracy: 0.7277 - val_loss: 0.5721 - val_accuracy: 0.7274
# Epoch 12/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2525 - accuracy: 0.7276 - val_loss: 0.5713 - val_accuracy: 0.7247
# Epoch 13/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2523 - accuracy: 0.7278 - val_loss: 0.5572 - val_accuracy: 0.7254
# Epoch 14/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2523 - accuracy: 0.7280 - val_loss: 0.5564 - val_accuracy: 0.7243
# Epoch 15/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2522 - accuracy: 0.7277 - val_loss: 0.5493 - val_accuracy: 0.7245
# Epoch 16/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2522 - accuracy: 0.7278 - val_loss: 0.5452 - val_accuracy: 0.7267
# Epoch 17/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2521 - accuracy: 0.7282 - val_loss: 0.5543 - val_accuracy: 0.7257
# Epoch 18/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2522 - accuracy: 0.7279 - val_loss: 0.5629 - val_accuracy: 0.7248
# Epoch 19/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2519 - accuracy: 0.7283 - val_loss: 0.5530 - val_accuracy: 0.7264
# Epoch 20/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2520 - accuracy: 0.7280 - val_loss: 0.5563 - val_accuracy: 0.7237
# Epoch 21/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2520 - accuracy: 0.7285 - val_loss: 0.5561 - val_accuracy: 0.7239
# Epoch 22/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2520 - accuracy: 0.7285 - val_loss: 0.5492 - val_accuracy: 0.7238
# Epoch 23/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2520 - accuracy: 0.7284 - val_loss: 0.5495 - val_accuracy: 0.7273
# Epoch 24/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2517 - accuracy: 0.7283 - val_loss: 0.5461 - val_accuracy: 0.7252
# Epoch 25/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2519 - accuracy: 0.7284 - val_loss: 0.5527 - val_accuracy: 0.7248
# Epoch 26/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2518 - accuracy: 0.7282 - val_loss: 0.5482 - val_accuracy: 0.7234
# ['he_normal', 0, 'elu']
# roc auc for validation set: 0.7995245996270703
# f1 score for validation set: 0.5804646550502904
# Epoch 1/100
# 9369/9369 [==============================] - 24s 2ms/step - loss: 0.2769 - accuracy: 0.6903 - val_loss: 0.5690 - val_accuracy: 0.7166
# Epoch 2/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2664 - accuracy: 0.7092 - val_loss: 0.5622 - val_accuracy: 0.7165
# Epoch 3/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2640 - accuracy: 0.7128 - val_loss: 0.5685 - val_accuracy: 0.7146
# Epoch 4/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2629 - accuracy: 0.7135 - val_loss: 0.5718 - val_accuracy: 0.7190
# Epoch 5/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2619 - accuracy: 0.7143 - val_loss: 0.5704 - val_accuracy: 0.7166
# Epoch 6/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2612 - accuracy: 0.7160 - val_loss: 0.5625 - val_accuracy: 0.7199
# Epoch 7/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2608 - accuracy: 0.7166 - val_loss: 0.5691 - val_accuracy: 0.7194
# Epoch 8/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2599 - accuracy: 0.7162 - val_loss: 0.5662 - val_accuracy: 0.7193
# Epoch 9/100
# 9369/9369 [==============================] - 24s 3ms/step - loss: 0.2597 - accuracy: 0.7165 - val_loss: 0.5665 - val_accuracy: 0.7198
# Epoch 10/100
# 9369/9369 [==============================] - 23s 3ms/step - loss: 0.2595 - accuracy: 0.7178 - val_loss: 0.5673 - val_accuracy: 0.7187
# Epoch 11/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2592 - accuracy: 0.7181 - val_loss: 0.5657 - val_accuracy: 0.7208
# Epoch 12/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2589 - accuracy: 0.7191 - val_loss: 0.5699 - val_accuracy: 0.7192
# ['he_normal', 0.2, 'relu']
# roc auc for validation set: 0.7947425325887411
# f1 score for validation set: 0.5692588745209013
# Epoch 1/100
# 9369/9369 [==============================] - 24s 2ms/step - loss: 0.2685 - accuracy: 0.7067 - val_loss: 0.5667 - val_accuracy: 0.7198
# Epoch 2/100
# 9369/9369 [==============================] - 23s 3ms/step - loss: 0.2632 - accuracy: 0.7151 - val_loss: 0.5642 - val_accuracy: 0.7203
# Epoch 3/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2616 - accuracy: 0.7170 - val_loss: 0.5659 - val_accuracy: 0.7189
# Epoch 4/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2605 - accuracy: 0.7186 - val_loss: 0.5642 - val_accuracy: 0.7216
# Epoch 5/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2599 - accuracy: 0.7193 - val_loss: 0.5617 - val_accuracy: 0.7209
# Epoch 6/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2595 - accuracy: 0.7194 - val_loss: 0.5562 - val_accuracy: 0.7222
# Epoch 7/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2592 - accuracy: 0.7204 - val_loss: 0.5566 - val_accuracy: 0.7218
# Epoch 8/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2589 - accuracy: 0.7205 - val_loss: 0.5571 - val_accuracy: 0.7224
# Epoch 9/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2585 - accuracy: 0.7209 - val_loss: 0.5559 - val_accuracy: 0.7220
# Epoch 10/100
# 9369/9369 [==============================] - 24s 3ms/step - loss: 0.2583 - accuracy: 0.7211 - val_loss: 0.5566 - val_accuracy: 0.7223
# Epoch 11/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2580 - accuracy: 0.7214 - val_loss: 0.5541 - val_accuracy: 0.7232
# Epoch 12/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2578 - accuracy: 0.7212 - val_loss: 0.5544 - val_accuracy: 0.7226
# Epoch 13/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2578 - accuracy: 0.7214 - val_loss: 0.5539 - val_accuracy: 0.7229
# Epoch 14/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2575 - accuracy: 0.7224 - val_loss: 0.5558 - val_accuracy: 0.7219
# Epoch 15/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2574 - accuracy: 0.7219 - val_loss: 0.5536 - val_accuracy: 0.7237
# Epoch 16/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2573 - accuracy: 0.7224 - val_loss: 0.5495 - val_accuracy: 0.7241
# Epoch 17/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2571 - accuracy: 0.7222 - val_loss: 0.5507 - val_accuracy: 0.7240
# Epoch 18/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2570 - accuracy: 0.7224 - val_loss: 0.5526 - val_accuracy: 0.7223
# Epoch 19/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2569 - accuracy: 0.7227 - val_loss: 0.5504 - val_accuracy: 0.7232
# Epoch 20/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2567 - accuracy: 0.7230 - val_loss: 0.5517 - val_accuracy: 0.7245
# Epoch 21/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2567 - accuracy: 0.7225 - val_loss: 0.5521 - val_accuracy: 0.7231
# Epoch 22/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2566 - accuracy: 0.7226 - val_loss: 0.5509 - val_accuracy: 0.7233
# Epoch 23/100
# 9369/9369 [==============================] - 24s 3ms/step - loss: 0.2565 - accuracy: 0.7229 - val_loss: 0.5494 - val_accuracy: 0.7242
# Epoch 24/100
# 9369/9369 [==============================] - 24s 3ms/step - loss: 0.2565 - accuracy: 0.7228 - val_loss: 0.5485 - val_accuracy: 0.7255
# Epoch 25/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2563 - accuracy: 0.7226 - val_loss: 0.5513 - val_accuracy: 0.7236
# Epoch 26/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2563 - accuracy: 0.7226 - val_loss: 0.5540 - val_accuracy: 0.7227
# Epoch 27/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2561 - accuracy: 0.7228 - val_loss: 0.5487 - val_accuracy: 0.7255
# Epoch 28/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2562 - accuracy: 0.7227 - val_loss: 0.5531 - val_accuracy: 0.7226
# Epoch 29/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2559 - accuracy: 0.7231 - val_loss: 0.5507 - val_accuracy: 0.7245
# Epoch 30/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2561 - accuracy: 0.7231 - val_loss: 0.5526 - val_accuracy: 0.7224
# Epoch 31/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2561 - accuracy: 0.7228 - val_loss: 0.5483 - val_accuracy: 0.7243
# Epoch 32/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2559 - accuracy: 0.7234 - val_loss: 0.5528 - val_accuracy: 0.7241
# Epoch 33/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2558 - accuracy: 0.7236 - val_loss: 0.5501 - val_accuracy: 0.7247
# Epoch 34/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2556 - accuracy: 0.7239 - val_loss: 0.5522 - val_accuracy: 0.7230
# Epoch 35/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2557 - accuracy: 0.7232 - val_loss: 0.5519 - val_accuracy: 0.7215
# Epoch 36/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2555 - accuracy: 0.7238 - val_loss: 0.5505 - val_accuracy: 0.7237
# Epoch 37/100
# 9369/9369 [==============================] - 24s 3ms/step - loss: 0.2556 - accuracy: 0.7237 - val_loss: 0.5497 - val_accuracy: 0.7250
# Epoch 38/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2555 - accuracy: 0.7232 - val_loss: 0.5479 - val_accuracy: 0.7246
# Epoch 39/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2554 - accuracy: 0.7236 - val_loss: 0.5525 - val_accuracy: 0.7228
# Epoch 40/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2555 - accuracy: 0.7234 - val_loss: 0.5487 - val_accuracy: 0.7249
# Epoch 41/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2554 - accuracy: 0.7239 - val_loss: 0.5528 - val_accuracy: 0.7241
# Epoch 42/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2555 - accuracy: 0.7239 - val_loss: 0.5484 - val_accuracy: 0.7246
# Epoch 43/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2554 - accuracy: 0.7235 - val_loss: 0.5511 - val_accuracy: 0.7233
# Epoch 44/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2552 - accuracy: 0.7237 - val_loss: 0.5492 - val_accuracy: 0.7242
# Epoch 45/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2553 - accuracy: 0.7238 - val_loss: 0.5486 - val_accuracy: 0.7246
# Epoch 46/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2553 - accuracy: 0.7243 - val_loss: 0.5490 - val_accuracy: 0.7250
# Epoch 47/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2553 - accuracy: 0.7234 - val_loss: 0.5521 - val_accuracy: 0.7218
# Epoch 48/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2553 - accuracy: 0.7236 - val_loss: 0.5505 - val_accuracy: 0.7229
# ['glorot_uniform', 0.2, 'elu']
# roc auc for validation set: 0.7969516534270513
# f1 score for validation set: 0.5859988140500192
# Epoch 1/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2657 - accuracy: 0.7079 - val_loss: 0.5670 - val_accuracy: 0.7208
# Epoch 2/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2575 - accuracy: 0.7232 - val_loss: 0.5661 - val_accuracy: 0.7232
# Epoch 3/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2553 - accuracy: 0.7256 - val_loss: 0.5705 - val_accuracy: 0.7207
# Epoch 4/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2542 - accuracy: 0.7264 - val_loss: 0.5579 - val_accuracy: 0.7278
# Epoch 5/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2536 - accuracy: 0.7271 - val_loss: 0.5669 - val_accuracy: 0.7234
# Epoch 6/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2531 - accuracy: 0.7278 - val_loss: 0.5567 - val_accuracy: 0.7260
# Epoch 7/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2527 - accuracy: 0.7280 - val_loss: 0.5542 - val_accuracy: 0.7241
# Epoch 8/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2524 - accuracy: 0.7282 - val_loss: 0.5592 - val_accuracy: 0.7250
# Epoch 9/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2522 - accuracy: 0.7286 - val_loss: 0.5551 - val_accuracy: 0.7247
# Epoch 10/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2520 - accuracy: 0.7285 - val_loss: 0.5577 - val_accuracy: 0.7234
# Epoch 11/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2519 - accuracy: 0.7288 - val_loss: 0.5471 - val_accuracy: 0.7289
# Epoch 12/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2517 - accuracy: 0.7287 - val_loss: 0.5448 - val_accuracy: 0.7264
# Epoch 13/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2515 - accuracy: 0.7288 - val_loss: 0.5407 - val_accuracy: 0.7269
# Epoch 14/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2515 - accuracy: 0.7290 - val_loss: 0.5445 - val_accuracy: 0.7253
# Epoch 15/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2514 - accuracy: 0.7289 - val_loss: 0.5531 - val_accuracy: 0.7246
# Epoch 16/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2514 - accuracy: 0.7292 - val_loss: 0.5440 - val_accuracy: 0.7277
# Epoch 17/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2512 - accuracy: 0.7293 - val_loss: 0.5431 - val_accuracy: 0.7275
# Epoch 18/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2511 - accuracy: 0.7290 - val_loss: 0.5445 - val_accuracy: 0.7254
# Epoch 19/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2510 - accuracy: 0.7294 - val_loss: 0.5405 - val_accuracy: 0.7270
# Epoch 20/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2511 - accuracy: 0.7290 - val_loss: 0.5469 - val_accuracy: 0.7235
# Epoch 21/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2511 - accuracy: 0.7294 - val_loss: 0.5432 - val_accuracy: 0.7243
# Epoch 22/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2511 - accuracy: 0.7294 - val_loss: 0.5418 - val_accuracy: 0.7246
# Epoch 23/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2510 - accuracy: 0.7293 - val_loss: 0.5421 - val_accuracy: 0.7278
# Epoch 24/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2508 - accuracy: 0.7294 - val_loss: 0.5430 - val_accuracy: 0.7251
# Epoch 25/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2509 - accuracy: 0.7297 - val_loss: 0.5503 - val_accuracy: 0.7261
# Epoch 26/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2508 - accuracy: 0.7296 - val_loss: 0.5463 - val_accuracy: 0.7247
# Epoch 27/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2508 - accuracy: 0.7299 - val_loss: 0.5359 - val_accuracy: 0.7304
# Epoch 28/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2508 - accuracy: 0.7297 - val_loss: 0.5456 - val_accuracy: 0.7241
# Epoch 29/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2507 - accuracy: 0.7298 - val_loss: 0.5446 - val_accuracy: 0.7278
# Epoch 30/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2506 - accuracy: 0.7300 - val_loss: 0.5435 - val_accuracy: 0.7240
# Epoch 31/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2506 - accuracy: 0.7299 - val_loss: 0.5473 - val_accuracy: 0.7275
# Epoch 32/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2507 - accuracy: 0.7300 - val_loss: 0.5611 - val_accuracy: 0.7259
# Epoch 33/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2507 - accuracy: 0.7297 - val_loss: 0.5402 - val_accuracy: 0.7268
# Epoch 34/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2506 - accuracy: 0.7299 - val_loss: 0.5473 - val_accuracy: 0.7246
# Epoch 35/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2506 - accuracy: 0.7296 - val_loss: 0.5565 - val_accuracy: 0.7246
# Epoch 36/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2505 - accuracy: 0.7297 - val_loss: 0.5418 - val_accuracy: 0.7273
# Epoch 37/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2505 - accuracy: 0.7301 - val_loss: 0.5484 - val_accuracy: 0.7274
# ['glorot_uniform', 0, 'relu']
# roc auc for validation set: 0.800841793623561
# f1 score for validation set: 0.5952017750658716
# Epoch 1/100
# 9369/9369 [==============================] - 24s 2ms/step - loss: 0.2710 - accuracy: 0.7070 - val_loss: 0.5629 - val_accuracy: 0.7203
# Epoch 2/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2635 - accuracy: 0.7142 - val_loss: 0.5640 - val_accuracy: 0.7205
# Epoch 3/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2619 - accuracy: 0.7171 - val_loss: 0.5663 - val_accuracy: 0.7194
# Epoch 4/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2612 - accuracy: 0.7177 - val_loss: 0.5663 - val_accuracy: 0.7215
# Epoch 5/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2606 - accuracy: 0.7185 - val_loss: 0.5635 - val_accuracy: 0.7210
# Epoch 6/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2601 - accuracy: 0.7184 - val_loss: 0.5628 - val_accuracy: 0.7236
# Epoch 7/100
# 9369/9369 [==============================] - 24s 3ms/step - loss: 0.2597 - accuracy: 0.7195 - val_loss: 0.5591 - val_accuracy: 0.7236
# Epoch 8/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2592 - accuracy: 0.7189 - val_loss: 0.5657 - val_accuracy: 0.7219
# Epoch 9/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2589 - accuracy: 0.7193 - val_loss: 0.5671 - val_accuracy: 0.7213
# Epoch 10/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2587 - accuracy: 0.7201 - val_loss: 0.5610 - val_accuracy: 0.7218
# Epoch 11/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2585 - accuracy: 0.7201 - val_loss: 0.5638 - val_accuracy: 0.7233
# Epoch 12/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2582 - accuracy: 0.7204 - val_loss: 0.5616 - val_accuracy: 0.7223
# Epoch 13/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2579 - accuracy: 0.7201 - val_loss: 0.5596 - val_accuracy: 0.7238
# Epoch 14/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2579 - accuracy: 0.7210 - val_loss: 0.5639 - val_accuracy: 0.7218
# Epoch 15/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2576 - accuracy: 0.7210 - val_loss: 0.5625 - val_accuracy: 0.7237
# Epoch 16/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2574 - accuracy: 0.7217 - val_loss: 0.5579 - val_accuracy: 0.7235
# Epoch 17/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2574 - accuracy: 0.7213 - val_loss: 0.5590 - val_accuracy: 0.7234
# Epoch 18/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2573 - accuracy: 0.7211 - val_loss: 0.5619 - val_accuracy: 0.7231
# Epoch 19/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2573 - accuracy: 0.7212 - val_loss: 0.5591 - val_accuracy: 0.7235
# Epoch 20/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2570 - accuracy: 0.7222 - val_loss: 0.5591 - val_accuracy: 0.7239
# Epoch 21/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2571 - accuracy: 0.7216 - val_loss: 0.5628 - val_accuracy: 0.7223
# Epoch 22/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2569 - accuracy: 0.7222 - val_loss: 0.5579 - val_accuracy: 0.7237
# Epoch 23/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2569 - accuracy: 0.7210 - val_loss: 0.5570 - val_accuracy: 0.7236
# Epoch 24/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2566 - accuracy: 0.7218 - val_loss: 0.5546 - val_accuracy: 0.7247
# Epoch 25/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2563 - accuracy: 0.7230 - val_loss: 0.5585 - val_accuracy: 0.7244
# Epoch 26/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2562 - accuracy: 0.7223 - val_loss: 0.5608 - val_accuracy: 0.7220
# Epoch 27/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2562 - accuracy: 0.7226 - val_loss: 0.5550 - val_accuracy: 0.7247
# Epoch 28/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2563 - accuracy: 0.7225 - val_loss: 0.5598 - val_accuracy: 0.7227
# Epoch 29/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2560 - accuracy: 0.7229 - val_loss: 0.5614 - val_accuracy: 0.7242
# Epoch 30/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2559 - accuracy: 0.7231 - val_loss: 0.5611 - val_accuracy: 0.7218
# Epoch 31/100
# 9369/9369 [==============================] - 24s 3ms/step - loss: 0.2560 - accuracy: 0.7229 - val_loss: 0.5573 - val_accuracy: 0.7240
# Epoch 32/100
# 9369/9369 [==============================] - 24s 3ms/step - loss: 0.2559 - accuracy: 0.7227 - val_loss: 0.5585 - val_accuracy: 0.7237
# Epoch 33/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2559 - accuracy: 0.7227 - val_loss: 0.5588 - val_accuracy: 0.7247
# Epoch 34/100
# 9369/9369 [==============================] - 24s 3ms/step - loss: 0.2558 - accuracy: 0.7228 - val_loss: 0.5626 - val_accuracy: 0.7229
# ['he_normal', 0.2, 'elu']
# roc auc for validation set: 0.7969571054685484
# f1 score for validation set: 0.5816527993230856
# Epoch 1/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2640 - accuracy: 0.7114 - val_loss: 0.5673 - val_accuracy: 0.7207
# Epoch 2/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2567 - accuracy: 0.7228 - val_loss: 0.5614 - val_accuracy: 0.7227
# Epoch 3/100
# 9369/9369 [==============================] - 23s 2ms/step - loss: 0.2551 - accuracy: 0.7245 - val_loss: 0.5639 - val_accuracy: 0.7208
# Epoch 4/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2541 - accuracy: 0.7252 - val_loss: 0.5457 - val_accuracy: 0.7268
# Epoch 5/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2536 - accuracy: 0.7263 - val_loss: 0.5604 - val_accuracy: 0.7217
# Epoch 6/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2530 - accuracy: 0.7274 - val_loss: 0.5518 - val_accuracy: 0.7266
# Epoch 7/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2527 - accuracy: 0.7274 - val_loss: 0.5470 - val_accuracy: 0.7234
# Epoch 8/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2526 - accuracy: 0.7280 - val_loss: 0.5656 - val_accuracy: 0.7243
# Epoch 9/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2523 - accuracy: 0.7283 - val_loss: 0.5566 - val_accuracy: 0.7254
# Epoch 10/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2520 - accuracy: 0.7282 - val_loss: 0.5561 - val_accuracy: 0.7246
# Epoch 11/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2519 - accuracy: 0.7285 - val_loss: 0.5618 - val_accuracy: 0.7284
# Epoch 12/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2518 - accuracy: 0.7286 - val_loss: 0.5555 - val_accuracy: 0.7278
# Epoch 13/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2517 - accuracy: 0.7288 - val_loss: 0.5501 - val_accuracy: 0.7260
# Epoch 14/100
# 9369/9369 [==============================] - 22s 2ms/step - loss: 0.2517 - accuracy: 0.7287 - val_loss: 0.5513 - val_accuracy: 0.7250
# ['he_normal', 0, 'relu']
# roc auc for validation set: 0.7992528787016642
# f1 score for validation set: 0.5868817958611013

# %%
 y_pred_test = model.predict(X_test)
  
print("roc auc for validation set:", roc_auc_score(y_test, y_pred_test))
y_pred_test_class = np.where(y_pred_test>0.5, 1, 0)
print("accuracy score for test set:", accuracy_score(y_test, y_pred_test_class))
print("f1 score for test set:", f1_score(y_test, y_pred_test_class))
# Out:
# roc auc for validation set: 0.802862580087294
# accuracy score for test set: 0.7265340431493416
# f1 score for test set: 0.5909757630788574
